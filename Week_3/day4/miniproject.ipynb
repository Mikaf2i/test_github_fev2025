# %%
import pandas as pd


import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm
from scipy import stats
from scipy.stats import pearsonr

# %%
dfapple = pd.read_csv('apple.csv')
dfapple.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close    Volume
# 0  02/01/1981  0.154018  0.155134  0.154018  0.154018   0.119849  21660800
# 1  05/01/1981  0.151228  0.151228  0.150670  0.150670   0.117244  35728000
# 2  06/01/1981  0.144531  0.144531  0.143973  0.143973   0.112032  45158400
# 3  07/01/1981  0.138393  0.138393  0.137835  0.137835   0.107256  55686400
# 4  08/01/1981  0.135603  0.135603  0.135045  0.135045   0.105085  39827200

# %%
dfapple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10608 entries, 0 to 10607
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       10608 non-null  object
#  1   Open       10608 non-null  float64
#  2   High       10608 non-null  float64
#  3   Low        10608 non-null  float64
#  4   Close      10608 non-null  float64
#  5   Adj Close  10608 non-null  float64
#  6   Volume     10608 non-null  int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 580.3+ KB

# %%
print(dfapple.columns)
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
dfapple.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count  10608.000000  10608.000000  10608.000000  10608.000000  10608.000000
# mean      16.689173     16.879955     16.500822     16.697362     16.027345
# std       35.450519     35.882848     35.031289     35.473912     35.154878
# min        0.049665      0.049665      0.049107      0.049107      0.038213
# 25%        0.287946      0.296875      0.282355      0.288923      0.238909
# 50%        0.488839      0.495536      0.480446      0.487701      0.404851
# 75%       16.320893     16.418483     16.151249     16.269554     14.073167
# max      182.630005    182.940002    179.119995    182.009995    180.959747
#
#              Volume
# count  1.060800e+04
# mean   3.275098e+08
# std    3.378203e+08
# min    0.000000e+00
# 25%    1.213044e+08
# 50%    2.145976e+08
# 75%    4.066804e+08
# max    7.421641e+09

# %%
dfapple['Date'] = pd.to_datetime(dfapple['Date'], dayfirst=True)
dfapple.set_index('Date', inplace=True)

# %%
plt.figure(figsize=(12, 6))
plt.plot(dfapple,label='test')

plt.title("Cours de clôture et le volume échangé au fil du temps")
plt.xlabel("Time")
plt.ylabel("Value")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(dfapple,label='test')

plt.title("Cours de clôture au fil du temps")
plt.xlabel("Close")
plt.ylabel("Time")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(dfapple,label='test')

plt.title("Cours de clôture et le volume échangé au fil du temps")
plt.xlabel("Volume")
plt.ylabel("Time")
plt.legend()
plt.show()

# %%
# %pip install mplfinance
import mplfinance as mpf
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import mplfinance as mpf

# Convertir la colonne Date en format datetime
df['Date'] = pd.to_datetime(df['Date'], format="%d/%m/%Y")

# Définir la colonne Date comme index
df.set_index('Date', inplace=True)

# Sélectionner une période pour le graphique (ex : les 100 premières lignes)
df_sample = df.iloc[:100]

# Créer le graphique en chandeliers
mpf.plot(df_sample, type='candle', style='charles', volume=False, title="Graphique en Chandeliers d'Apple")

# Affichage du graphique
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 5
#       2 import mplfinance as mpf
#       4 # Convertir la colonne Date en format datetime
# ----> 5 df['Date'] = pd.to_datetime(df['Date'], format="%d/%m/%Y")
#       7 # Définir la colonne Date comme index
#       8 df.set_index('Date', inplace=True)
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
import mplfinance as mpf

# Charger les données
dfapple = pd.read_csv("apple.csv", parse_dates=["Date"], dayfirst=True)
dfapple.set_index("Date", inplace=True)

# Afficher un graphique en chandeliers
mpf.plot(dfapple.iloc[:500], type='candle', style='charles', title="Graphique en Chandeliers d'Apple")
