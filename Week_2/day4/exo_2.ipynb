# %%
import matplotlib.pyplot as plt


categories = ['mon', 'tue', 'wed', 'thu', 'fri', 'sat', 'sun']
values = [72, 74, 76, 80, 82, 78, 75]

plt.plot(categories, values)
plt.title('exo 2')
plt.xlabel('Jours')
plt.ylabel('Temperature')
plt.show()
