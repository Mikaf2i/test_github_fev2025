# %%
import matplotlib.pyplot as plt
from PIL import Image, ImageOps
from scipy.ndimage import rotate

image_path = '0001.png'
original_image = Image.open(image_path)

plt.imshow(original_image)
plt.title("Image Originale")
plt.show()

def rotate_image_30_degrees(image):
    return rotate(image, 30, reshape=True)

rotated_image = rotate_image_30_degrees(original_image)


plt.imshow(rotated_image)
plt.title("Image Pivotée de 30°")
plt.show()


flipped_horizontally = ImageOps.mirror(original_image)

plt.imshow(flipped_horizontally)
plt.title("Image Retournée Horizontalement")
plt.show()


flipped_vertically = ImageOps.flip(original_image)

plt.imshow(flipped_vertically)
plt.title("Image Retournée Verticalement")
plt.show()


zoom_factor = 1.2
new_size = (int(original_image.width * zoom_factor), int(original_image.height * zoom_factor))
zoomed_image = original_image.resize(new_size, Image.LANCZOS)

plt.imshow(zoomed_image)
plt.title("Image Zoomée (1.2x)")
plt.show()
